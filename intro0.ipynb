# %%
import ipython
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fa10df20f905> in <module>
# ----> 1 import ipython
#
# ModuleNotFoundError: No module named 'ipython'

# %%
from math import sqrt,sin,pi
from numpy import empty
from pylab import imshow,gray,show

wavelength = 5.0
k = 2*pi/wavelength
xi0 = 1.0
separation = 20.0      # Separation of centers in cm
side = 100.0           # Side of the square in cm
points = 500           # Number of grid points along each side
spacing = side/points  # Spacing of points in cm


# Calculate the positions of the centers of the circles
x1 = side/2 + separation/2
y1 = side/2
x2 = side/2 - separation/2
y2 = side/2

# Make an array to store the heights
xi = empty([points,points],float)

# Calculate the values in the array
for i in range(points):
    y = spacing*i
    for j in range(points):
        x = spacing*j
        r1 = sqrt((x-x1)**2+(y-y1)**2)
        r2 = sqrt((x-x2)**2+(y-y2)**2)
        xi[i,j] = xi0*sin(k*r1) + xi0*sin(k*r2)

# Make the plot
imshow(xi,origin="lower",extent=[0,side,0,side])
gray()
show()

# %%
plot(x,y,'rx')
title('My first graph')
xlabel('Time (fortnights)')
ylabel('Distance (furlongs)')
xlim(0, 6)
ylim(0, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c7f8f099aef> in <module>
# ----> 1 plot(x,y,'rx')
#       2 title('My first graph')
#       3 xlabel('Time (fortnights)')
#       4 ylabel('Distance (furlongs)')
#       5 xlim(0, 6)
#
# NameError: name 'plot' is not defined

# %%
18/38
# Out:
# 0.47368421052631576

# %%
import random
from matplotlib import pyplot as plt
import numpy as np

ini = 2000
mini = 50

apuesta = mini
din = ini
dinero=[ini]
while din>0:
    if random.random() < 18/38:
        din = din-apuesta
        apuesta = min(apuesta*2,din)
    else:
        din = din + apuesta
        apuesta = mini
    dinero.append(din)
        
print(dinero)
plt.plot(dinero)
# Out:
# [2000, 1950, 2050, 2100, 2050, 2150, 2100, 2000, 1800, 2200, 2250, 2200, 2300, 2250, 2350, 2400, 2350, 2250, 2450, 2500, 2550, 2500, 2400, 2600, 2550, 2450, 2250, 1850, 2650, 2700, 2750, 2700, 2600, 2400, 2800, 2750, 2850, 2800, 2700, 2900, 2850, 2950, 3000, 2950, 2850, 3050, 3000, 3100, 3050, 2950, 2750, 2350, 3150, 3200, 3150, 3050, 2850, 3250, 3200, 3300, 3350, 3300, 3200, 3400, 3450, 3500, 3450, 3550, 3500, 3400, 3600, 3550, 3450, 3650, 3600, 3700, 3650, 3750, 3700, 3800, 3750, 3850, 3900, 3850, 3750, 3950, 3900, 3800, 3600, 4000, 3950, 4050, 4000, 4100, 4050, 3950, 3750, 3350, 2550, 950, 1900, 1950, 2000, 2050, 2100, 2150, 2200, 2150, 2050, 2250, 2300, 2250, 2150, 2350, 2300, 2400, 2350, 2450, 2500, 2450, 2550, 2500, 2400, 2200, 2600, 2650, 2600, 2500, 2700, 2650, 2550, 2750, 2800, 2850, 2900, 2850, 2950, 3000, 3050, 3100, 3050, 2950, 2750, 3150, 3200, 3250, 3300, 3250, 3350, 3400, 3450, 3400, 3300, 3500, 3550, 3600, 3650, 3700, 3750, 3800, 3850, 3900, 3950, 4000, 3950, 4050, 4100, 4050, 4150, 4100, 4200, 4250, 4200, 4300, 4250, 4150, 4350, 4300, 4200, 4000, 3600, 4400, 4350, 4250, 4450, 4400, 4300, 4100, 4500, 4550, 4500, 4400, 4200, 3800, 3000, 4600, 4550, 4450, 4650, 4600, 4500, 4300, 4700, 4650, 4750, 4700, 4600, 4800, 4850, 4900, 4950, 5000, 4950, 5050, 5000, 5100, 5050, 4950, 4750, 4350, 5150, 5100, 5200, 5150, 5250, 5200, 5300, 5350, 5300, 5400, 5350, 5250, 5050, 5450, 5400, 5300, 5500, 5550, 5600, 5650, 5700, 5650, 5550, 5750, 5800, 5850, 5800, 5700, 5500, 5100, 5900, 5950, 6000, 5950, 5850, 5650, 6050, 6000, 5900, 6100, 6050, 5950, 6150, 6200, 6150, 6250, 6200, 6100, 5900, 5500, 6300, 6250, 6150, 5950, 6350, 6400, 6350, 6450, 6500, 6550, 6600, 6550, 6450, 6250, 5850, 6650, 6600, 6500, 6700, 6650, 6550, 6750, 6800, 6850, 6800, 6900, 6850, 6950, 7000, 7050, 7100, 7050, 6950, 6750, 6350, 5550, 3950, 7150, 7200, 7250, 7300, 7350, 7300, 7400, 7450, 7400, 7500, 7550, 7600, 7550, 7650, 7700, 7650, 7550, 7750, 7700, 7600, 7400, 7800, 7850, 7900, 7850, 7750, 7950, 8000, 7950, 8050, 8000, 8100, 8050, 7950, 7750, 7350, 6550, 4950, 1750, 3500, 3450, 3550, 3500, 3600, 3650, 3700, 3750, 3800, 3850, 3900, 3850, 3750, 3950, 3900, 4000, 3950, 4050, 4000, 4100, 4050, 3950, 4150, 4100, 4000, 4200, 4250, 4300, 4350, 4400, 4350, 4450, 4500, 4550, 4600, 4550, 4450, 4650, 4700, 4750, 4700, 4800, 4850, 4800, 4900, 4950, 4900, 5000, 5050, 5000, 5100, 5150, 5200, 5150, 5050, 5250, 5300, 5250, 5350, 5400, 5450, 5500, 5450, 5550, 5600, 5550, 5650, 5600, 5700, 5650, 5750, 5800, 5750, 5850, 5900, 5950, 6000, 6050, 6100, 6150, 6200, 6250, 6300, 6350, 6400, 6350, 6250, 6050, 6450, 6400, 6500, 6550, 6600, 6650, 6700, 6650, 6750, 6800, 6750, 6850, 6900, 6950, 7000, 6950, 6850, 7050, 7000, 7100, 7050, 7150, 7100, 7200, 7250, 7200, 7300, 7250, 7350, 7400, 7450, 7500, 7550, 7600, 7550, 7650, 7600, 7700, 7750, 7800, 7850, 7800, 7700, 7500, 7900, 7950, 8000, 7950, 7850, 8050, 8000, 8100, 8050, 8150, 8100, 8000, 7800, 8200, 8250, 8300, 8250, 8350, 8400, 8350, 8250, 8050, 8450, 8400, 8300, 8500, 8450, 8350, 8550, 8500, 8600, 8650, 8700, 8750, 8800, 8850, 8800, 8700, 8500, 8900, 8950, 8900, 8800, 9000, 8950, 8850, 9050, 9100, 9050, 8950, 9150, 9100, 9000, 9200, 9250, 9300, 9350, 9400, 9450, 9400, 9300, 9100, 8700, 7900, 6300, 9500, 9550, 9500, 9400, 9200, 8800, 8000, 9600, 9650, 9700, 9750, 9700, 9800, 9850, 9900, 9850, 9750, 9950, 10000, 9950, 10050, 10100, 10150, 10200, 10250, 10300, 10350, 10300, 10400, 10450, 10500, 10550, 10500, 10600, 10650, 10700, 10750, 10800, 10850, 10800, 10700, 10900, 10850, 10950, 11000, 10950, 11050, 11100, 11150, 11200, 11250, 11300, 11250, 11150, 10950, 11350, 11400, 11450, 11500, 11450, 11350, 11550, 11600, 11550, 11450, 11650, 11700, 11650, 11550, 11750, 11800, 11850, 11900, 11850, 11950, 11900, 11800, 12000, 12050, 12000, 12100, 12050, 12150, 12100, 12000, 12200, 12250, 12200, 12300, 12250, 12150, 12350, 12400, 12450, 12500, 12450, 12550, 12600, 12650, 12700, 12650, 12750, 12800, 12850, 12800, 12900, 12950, 12900, 13000 ...

# %%
import numpy as np
np.array([12,3],int)
# Out:
# array([12,  3])

# %%
np.loadtxt('as')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-010853c64e3e> in <module>
# ----> 1 np.loadtxt('as')
#
# c:\users\tbasi\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# c:\users\tbasi\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# c:\users\tbasi\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: as not found.
